# %%
import numpy as np
import pickle
import pandas as pd
import h5py
import pandas as pd
from tsfresh import extract_features, select_features
from tsfresh.feature_extraction import EfficientFCParameters
import multiprocessing
import os
import re
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.cluster import KMeans
import h5py
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
from sklearn.cluster import KMeans
from collections import Counter
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
import numpy as np

# %%
x_df = pd.read_pickle("featuresTest/featuresTestAll/all_features_test.pkl")
x_df.head()
print("Shape de X_df", x_df.shape)
# Out:
# Shape de X_df (205, 777)

# %% [markdown]
# Cargamos nuestro árbol

# %%
import decisionTree as dt
from decisionTree import DecisionTree,  discretize_all  

class CustomUnpickler(pickle.Unpickler):
    def find_class(self, module, name):
        if module == "__main__":
            module = "decisionTree"
        return super().find_class(module, name)

with open('precision_best.pkl', 'rb') as f:
    tree = CustomUnpickler(f).load()

x_df_discretized = discretize_all(x_df)
X_test = x_df_discretized.values 

predictions = tree.predict(X_test)
# Out:
# /home/marce/Documentos/Ciclo6/Machine Learning/Proyecto1/project-1-classification-2025-1-b/venv/lib/python3.11/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (2). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/marce/Documentos/Ciclo6/Machine Learning/Proyecto1/project-1-classification-2025-1-b/venv/lib/python3.11/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (2). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/marce/Documentos/Ciclo6/Machine Learning/Proyecto1/project-1-classification-2025-1-b/venv/lib/python3.11/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (2). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# ...

# %%
results_df = pd.DataFrame({
    "ID": range(1, len(predictions) + 1),
    "result": predictions
})

results_df.to_csv("precision_best.csv", index=False)

# %%
import decisionTree as dt
from decisionTree import DecisionTree,  discretize_all  

# Creamos un unpickle debido a que el archivo fue creado en el ipynb y no en el py
class CustomUnpickler(pickle.Unpickler):
    def find_class(self, module, name):
        if module == "__main__":
            module = "decisionTree"
        return super().find_class(module, name)

with open('best_trees-depht6.pkl', 'rb') as f:
    tree = CustomUnpickler(f).load()

x_df_discretized = discretize_all(x_df)
X_test = x_df_discretized.values 

predictions = tree.predict(X_test)
results_df = pd.DataFrame({
    "ID": range(1, len(predictions) + 1),
    "result": predictions
})

results_df.to_csv("predicciones-depth6.csv", index=False)
# Out:
# /home/marce/Documentos/Ciclo6/Machine Learning/Proyecto1/project-1-classification-2025-1-b/venv/lib/python3.11/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (2). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/marce/Documentos/Ciclo6/Machine Learning/Proyecto1/project-1-classification-2025-1-b/venv/lib/python3.11/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (2). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /home/marce/Documentos/Ciclo6/Machine Learning/Proyecto1/project-1-classification-2025-1-b/venv/lib/python3.11/site-packages/sklearn/base.py:1389: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (2). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# ...

# %% [markdown]
# Prueba con svm

# %%
import numpy as np
from svm import SVM 
import pandas as pd
import pickle
x_df_svm = pd.read_pickle("featuresTest/featuresTestAll/all_features_test.pkl")
x_df_svm.head()
print("Shape de X_df", x_df_svm.shape)


class CustomUnpicklersvm(pickle.Unpickler):
    def find_class(self, module, name):
        if module == "__main__":
            module = "svm"
        return super().find_class(module, name)

with open('mejor_modelo_svm_sigmoid.pkl', 'rb') as f:
    svm = CustomUnpicklersvm(f).load()


predictions = svm.predict(x_df_svm)


results_df = pd.DataFrame({
    "ID": range(1, len(predictions) + 1),
    "result": predictions
})

results_df.to_csv("predicciones-svm.csv", index=False)
# Out:
# Shape de X_df (205, 777)

# %%
class CustomUnpicklersvm(pickle.Unpickler):
    def find_class(self, module, name):
        if module == "__main__":
            module = "svm"
        return super().find_class(module, name)

with open('simple_svm_sigmoid.pkl', 'rb') as f:
    svm = CustomUnpicklersvm(f).load()


predictions = svm.predict(x_df_svm)


results_df = pd.DataFrame({
    "ID": range(1, len(predictions) + 1),
    "result": predictions
})

results_df.to_csv("simple_svm_sigmoid-svm.csv", index=False)
